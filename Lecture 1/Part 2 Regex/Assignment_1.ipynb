# %% [markdown]
# # Tutorial 1
# Introduction to Computational Linguistics
# <br>
# Winter Semester 2023/2024
# <br>
# Saarland University
#
# Prof. Dr. Demberg

# %% [markdown]
# ## Python assignment: 👩‍💼 Running the Eliza Chatbot 👩‍💼
#
# ---
#
#
# Follow the tutorial below and try out the Eliza chatbot implemented in NLTK.

# %% [markdown]
# # Question 1: Run Eliza
#
# Run the Eliza chatbot and interact with it.
#
# 1. Start by executing the three code cells below. Cells can be excuted with ctrl+enter or with the run icon on the top.
#
# 2. Once you run the `demo()` function, you can start chatting with Eliza. Type in your responses in the input box and press enter.

# %% [markdown]
# Import the necessary libraries.

# %%
from __future__ import print_function
from nltk.chat.util import Chat, reflections

# %% [markdown]
# ### Rules of Eliza
#
# The bulk of Eliza is just a set of rules.  Each rule consists of
# - A regular expression that should be matched against what the user says.  If there is a match, that means that this rule can apply to generate possible responses for the therapist.
# - A list of possible responses.  The therapist picks one of these responses at random.  The responses can have expressions of the form `%n` inside them.  These will be replaced with the translation of group number `n` from the regular expression match.
# This version of Eliza has many different rules.  You can imagine that this table could get pretty big and it would potentially lead to more complex and interesting behavior.
#
# *Try executing the two cells below (first one for rules, second one for running Eliza).*
#
# *See what utterance triggers these rules.*
#
#
# **Note:** You can run the code in the cell below by clicking on the cell and pressing `Shift + Enter`.

# %%
# a table of response pairs, where each pair consists of a
# regular expression, and a list of possible responses,
# with group-macros labelled as %1, %2.

pairs = [
    ['How are you?',
      [ "I'm fine, thank you."]],
    ["I need (.*)",
    [   "Why do you need %1?", # %1 is a placeholder for the first group
        "Would it really help you to get %1?",
        "Are you sure you need %1?"]],
    ["Why don't you (.*)",
    [   "Do you really think I don't %1?",
        "Perhaps eventually I will %1.",
        "Do you really want me to %1?"]],
    ["Why can't I (.*)",
    [   "Do you think you should be able to %1?",
        "If you could %1, what would you do?",
        "I don't know -- why can't you %1?",
        "Have you really tried?"]],
    ["I can't (.*)",
    [   "How do you know you can't %1?",
        "Perhaps you could %1 if you tried.",
        "What would it take for you to %1?"]],
    ["I am (.*)",
    [   "Did you come to me because you are %1?",
        "How long have you been %1?",
        "How do you feel about being %1?"]],
    ["I'm (.*)",
    [   "How does being %1 make you feel?",
        "Do you enjoy being %1?",
        "Why do you tell me you're %1?",
        "Why do you think you're %1?"]],
    ["Are you (.*)",
    [   "Why does it matter whether I am %1?",
        "Would you prefer it if I were not %1?",
        "Perhaps you believe I am %1.",
        "I may be %1 -- what do you think?"]],
    ["What (.*)",
    [   "Why do you ask?",
        "How would an answer to that help you?",
        "What do you think?"]],
    ["How (.*)",
    [   "How do you suppose?",
        "Perhaps you can answer your own question.",
        "What is it you're really asking?"]],
    ["Because (.*)",
    [   "Is that the real reason?",
        "What other reasons come to mind?",
        "Does that reason apply to anything else?",
        "If %1, what else must be true?"]],
    ["(.*) sorry (.*)",
    [   "There are many times when no apology is needed.",
        "What feelings do you have when you apologize?"]],
    ["Hello(.*)",
    [   "Hello... I'm glad you could drop by today.",
        "Hi there... how are you today?",
        "Hello, how are you feeling today?"]],
    ["I think (.*)",
    [   "Do you doubt %1?",
        "Do you really think so?",
        "But you're not sure %1?"]],
    ["(.*) friend(.*)",
    [   "Tell me more about your friends.",
        "When you think of a friend, what comes to mind?",
        "Why don't you tell me about a childhood friend?"]],
    ["Yes",
    [   "You seem quite sure.",
        "OK, but can you elaborate a bit?"]],
    ["No",
    [ "Why not?"]],
    ["(.*) computer(.*)",
    [   "Are you really talking about me?",
        "Does it seem strange to talk to a computer?",
        "How do computers make you feel?",
        "Do you feel threatened by computers?"]],
    ["Is it (.*)",
    [   "Do you think it is %1?",
        "Perhaps it's %1 -- what do you think?",
        "If it were %1, what would you do?",
        "It could well be that %1."]],
    ["It is (.*)",
    [   "You seem very certain.",
        "If I told you that it probably isn't %1, what would you feel?"]],
    ["Can you (.*)",
    [   "What makes you think I can't %1?",
        "If I could %1, then what?",
        "Why do you ask if I can %1?"]],
    ["Can I (.*)",
    [   "Perhaps you don't want to %1.",
        "Do you want to be able to %1?",
        "If you could %1, would you?"]],
    ["You are (.*)",
    [   "Why do you think I am %1?",
        "Does it please you to think that I'm %1?",
        "Perhaps you would like me to be %1.",
        "Perhaps you're really talking about yourself?"]],
    ["You're (.*)",
    [   "Why do you say I am %1?",
        "Why do you think I am %1?",
        "Are we talking about you, or me?"]],
    ["I don't (.*)",
    [   "Don't you really %1?",
        "Why don't you %1?",
        "Do you want to %1?"]],
    ["I feel (.*)",
    [   "Good, tell me more about these feelings.",
        "Do you often feel %1?",
        "When do you usually feel %1?",
        "When you feel %1, what do you do?"]],
    ["I have (.*)",
    [   "Why do you tell me that you've %1?",
        "Have you really %1?",
        "Now that you have %1, what will you do next?"]],
    ["I would (.*)",
    [   "Could you explain why you would %1?",
        "Why would you %1?",
        "Who else knows that you would %1?"]],
    ["Is there (.*)",
    [   "Do you think there is %1?",
        "It's likely that there is %1.",
        "Would you like there to be %1?"]],
    ["My (.*)",
    [   "I see, your %1.",
        "Why do you say that your %1?",
        "When your %1, how do you feel?"]],
    ["You (.*)",
    [   "We should be discussing you, not me.",
        "Why do you say that about me?",
        "Why do you care whether I %1?"]],
    ["Why (.*)",
    [   "Why don't you tell me the reason why %1?",
        "Why do you think %1?" ]],
    ["I want (.*)",
    [   "What would it mean to you if you got %1?",
        "Why do you want %1?",
        "What would you do if you got %1?",
        "If you got %1, then what would you do?"]],
    ["(.*) mother(.*)",
    [   "Tell me more about your mother.",
        "What was your relationship with your mother like?",
        "How do you feel about your mother?",
        "How does this relate to your feelings today?",
        "Good family relations are important."]],
    ["(.*) father(.*)",
    [   "Tell me more about your father.",
        "How did your father make you feel?",
        "How do you feel about your father?",
        "Does your relationship with your father relate to your feelings today?",
        "Do you have trouble showing affection with your family?"]],
    ["(.*) child(.*)",
    [   "Did you have close friends as a child?",
        "What is your favorite childhood memory?",
        "Do you remember any dreams or nightmares from childhood?",
        "Did the other children sometimes tease you?",
        "How do you think your childhood experiences relate to your feelings today?"]],
    ["(.*)\?",
    [   "Why do you ask that?",
        "Please consider whether you can answer your own question.",
        "Perhaps the answer lies within yourself?",
        "Why don't you tell me?"]],
    ["quit",
    [   "Thank you for talking with me.",
        "Good-bye.",
        "Thank you, that will be $150.  Have a good day!"]],
  ["(.*)",
  [   "Please tell me more.",
      "Let's change focus a bit... Tell me about your family.",
      "Can you elaborate on that?",
      "Why do you say that %1?",
      "I see.",
      "Very interesting.",
      "%1.",
      "I see.  And what does that tell you?",
      "How does that make you feel?",
      "How do you feel when you say that?"]]
]

# %% [markdown]
# The cell below implements the chatbot. Please do the following:
#
# 1. Try and run the cell below.
# 2. You will see an input field at the top. Write your dialogue in the cell.
# 3. Observe the chatbot response generated in the same cell's output.
# 4. *See which rule triggers which response.*
#
# For example, you can try the following questions with Eliza:
# 1. Hello Eliza
# 2. My homework will be talking with you.
# 3. I am very happy today.
# 4. Why do I still feel sad?
#
# Think of more examples to talk to Eliza.

# %%
eliza_chatbot = Chat(pairs, reflections)

def eliza_chat():
    print("Therapist\n---------")
    print("Talk to the program by typing in plain English, using normal upper-")
    print('and lower-case letters and punctuation.  Enter "quit" when done.')
    print('='*72)
    print("Hello.  How are you feeling today?")

    eliza_chatbot.converse()

def demo():
    eliza_chat()


if __name__ == "__main__":
    demo()
# Out:
# Therapist
# ---------
# Talk to the program by typing in plain English, using normal upper-
# and lower-case letters and punctuation.  Enter "quit" when done.
# ========================================================================
# Hello.  How are you feeling today?
# Hello... I'm glad you could drop by today.
# I see, your homework is talking with me.
# How do you feel about being very happy today?
# Why do you think do you still feel sad?
# Thank you, that will be $150.  Have a good day!

# %% [markdown]
# ### Your assignment code
#
# Your assignment code is given below. Jump down two cells below to see Question 2 of the assignment.
#
# The two cells below are for answering question 3 onwards.

# %%
# a table of response pairs, where each pair consists of a
# regular expression, and a list of possible responses,
# with group-macros labelled as %1, %2.

#The answers to questoion 3 onwards need to be entered in this cell in the space marked "Add Answers 3-7 here:"

pairs_assignment = [
    ['How are you?',
      [ "I'm fine, thank you."]],
    ["I need (.*)",
    [   "Why do you need %1?", # %1 is a placeholder for the first group
        "Would it really help you to get %1?",
        "Are you sure you need %1?"]],
    ["Why don't you (.*)",
    [   "Do you really think I don't %1?",
        "Perhaps eventually I will %1.",
        "Do you really want me to %1?"]],
    ["Why can't I (.*)",
    [   "Do you think you should be able to %1?",
        "If you could %1, what would you do?",
        "I don't know -- why can't you %1?",
        "Have you really tried?"]],
    ["I can't (.*)",
    [   "How do you know you can't %1?",
        "Perhaps you could %1 if you tried.",
        "What would it take for you to %1?"]],
    ["I am (.*)",
    [   "Did you come to me because you are %1?",
        "How long have you been %1?",
        "How do you feel about being %1?"]],
    ["I'm (.*)",
    [   "How does being %1 make you feel?",
        "Do you enjoy being %1?",
        "Why do you tell me you're %1?",
        "Why do you think you're %1?"]],
    ["Are you (.*)",
    [   "Why does it matter whether I am %1?",
        "Would you prefer it if I were not %1?",
        "Perhaps you believe I am %1.",
        "I may be %1 -- what do you think?"]],
    ["What (.*)",
    [   "Why do you ask?",
        "How would an answer to that help you?",
        "What do you think?"]],
    ["How (.*)",
    [   "How do you suppose?",
        "Perhaps you can answer your own question.",
        "What is it you're really asking?"]],
    ["Because (.*)",
    [   "Is that the real reason?",
        "What other reasons come to mind?",
        "Does that reason apply to anything else?",
        "If %1, what else must be true?"]],
    ["(.*) sorry (.*)",
    [   "There are many times when no apology is needed.",
        "What feelings do you have when you apologize?"]],
    ["Hello(.*)",
    [   "Hello... I'm glad you could drop by today.",
        "Hi there... how are you today?",
        "Hello, how are you feeling today?"]],
    ["I think (.*)",
    [   "Do you doubt %1?",
        "Do you really think so?",
        "But you're not sure %1?"]],
    ["(.*) friend(.*)",
    [   "Tell me more about your friends.",
        "When you think of a friend, what comes to mind?",
        "Why don't you tell me about a childhood friend?"]],
    ["Yes",
    [   "You seem quite sure.",
        "OK, but can you elaborate a bit?"]],
    ["No",
    [ "Why not?"]],
    ["(.*) computer(.*)",
    [   "Are you really talking about me?",
        "Does it seem strange to talk to a computer?",
        "How do computers make you feel?",
        "Do you feel threatened by computers?"]],
    ["Is it (.*)",
    [   "Do you think it is %1?",
        "Perhaps it's %1 -- what do you think?",
        "If it were %1, what would you do?",
        "It could well be that %1."]],
    ["It is (.*)",
    [   "You seem very certain.",
        "If I told you that it probably isn't %1, what would you feel?"]],
    ["Can you (.*)",
    [   "What makes you think I can't %1?",
        "If I could %1, then what?",
        "Why do you ask if I can %1?"]],
    ["Can I (.*)",
    [   "Perhaps you don't want to %1.",
        "Do you want to be able to %1?",
        "If you could %1, would you?"]],

    ################################################################################################
    ################################################################################################
    ################################################################################################
    #Hint: you can copy paste the patterns above to make new rules

    # Add Answers 3-7 here:


    ################################################################################################
    ### Answer to question 3:

    


    # ################################################################################################
    ### Answer to question 4:



    ################################################################################################
    ### Answer to question 5:

    




    ################################################################################################
    ### Answer to question 6:

    



    # ################################################################################################
    ### Answer to question 7:

    


    ################################################################################################
    ################################################################################################
    ################################################################################################

    
    ["You are (.*)",
    [   "Why do you think I am %1?",
        "Does it please you to think that I'm %1?",
        "Perhaps you would like me to be %1.",
        "Perhaps you're really talking about yourself?"]],
    ["You're (.*)",
    [   "Why do you say I am %1?",
        "Why do you think I am %1?",
        "Are we talking about you, or me?"]],
    ["I don't (.*)",
    [   "Don't you really %1?",
        "Why don't you %1?",
        "Do you want to %1?"]],
    ["I feel (.*)",
    [   "Good, tell me more about these feelings.",
        "Do you often feel %1?",
        "When do you usually feel %1?",
        "When you feel %1, what do you do?"]],
    ["I have (.*)",
    [   "Why do you tell me that you've %1?",
        "Have you really %1?",
        "Now that you have %1, what will you do next?"]],
    ["I would (.*)",
    [   "Could you explain why you would %1?",
        "Why would you %1?",
        "Who else knows that you would %1?"]],
    ["Is there (.*)",
    [   "Do you think there is %1?",
        "It's likely that there is %1.",
        "Would you like there to be %1?"]],
    ["My (.*)",
    [   "I see, your %1.",
        "Why do you say that your %1?",
        "When your %1, how do you feel?"]],
    ["You (.*)",
    [   "We should be discussing you, not me.",
        "Why do you say that about me?",
        "Why do you care whether I %1?"]],
    ["Why (.*)",
    [   "Why don't you tell me the reason why %1?",
        "Why do you think %1?" ]],
    ["I want (.*)",
    [   "What would it mean to you if you got %1?",
        "Why do you want %1?",
        "What would you do if you got %1?",
        "If you got %1, then what would you do?"]],
    ["(.*) mother(.*)",
    [   "Tell me more about your mother.",
        "What was your relationship with your mother like?",
        "How do you feel about your mother?",
        "How does this relate to your feelings today?",
        "Good family relations are important."]],
    ["(.*) father(.*)",
    [   "Tell me more about your father.",
        "How did your father make you feel?",
        "How do you feel about your father?",
        "Does your relationship with your father relate to your feelings today?",
        "Do you have trouble showing affection with your family?"]],
    ["I am working on (.*) through (.*)",
     [  "Tell me more about %1. And why do you think it can acheived by %2?"]], #identifying multiple groups in a single sentence
    ["(.*) child(.*)",
    [   "Did you have close friends as a child?",
        "What is your favorite childhood memory?",
        "Do you remember any dreams or nightmares from childhood?",
        "Did the other children sometimes tease you?",
        "How do you think your childhood experiences relate to your feelings today?"]],
    ["(.*)\?",
    [   "Why do you ask that?",
        "Please consider whether you can answer your own question.",
        "Perhaps the answer lies within yourself?",
        "Why don't you tell me?"]],
    ["quit",
    [   "Thank you for talking with me.",
        "Good-bye.",
        "Thank you, that will be $150.  Have a good day!"]],
  ["(.*)",
  [   "Please tell me more.",
      "Let's change focus a bit... Tell me about your family.",
      "Can you elaborate on that?",
      "Why do you say that %1?",
      "I see.",
      "Very interesting.",
      "%1.",
      "I see.  And what does that tell you?",
      "How does that make you feel?",
      "How do you feel when you say that?"]]
]

# %%
eliza_chatbot_assignment = Chat(pairs_assignment, reflections)

def eliza_chat_assignment():
    print("Therapist\n---------")
    print("Talk to the program by typing in plain English, using normal upper-")
    print('and lower-case letters and punctuation.  Enter "quit" when done.')
    print('='*72)
    print("Hello.  How are you feeling today?")

    eliza_chatbot_assignment.converse()

def demo_assignment():
    eliza_chat_assignment()


if __name__ == "__main__":
    demo_assignment()
# Out:
# Therapist
# ---------
# Talk to the program by typing in plain English, using normal upper-
# and lower-case letters and punctuation.  Enter "quit" when done.
# ========================================================================
# Hello.  How are you feeling today?
# Hello, how are you feeling today?
# How does this relate to your feelings today?
# What was your relationship with your mother like?
# Does your relationship with your father relate to your feelings today?
# I think you meant 'mother' instead of 'mther'. Tell me more about your mother.
# Thank you for talking with me.

# %% [markdown]
# # Question 2: Write about limitations
#
# Think about the regex in the eliza chat. What are some of the limitations of the regex in pairs_original? How would you improve the regex in pairs_original?
#
# Add your answer to the markdown cell below.

# %% [markdown]
# # Answer 2:
#
# <font color="red">
# #################################Write your answer here######################################################################
# </font>

# %% [markdown]
# # Question 3: Spelling Correction
#
# Insert additional regex for pairs variable for spelling errors:
#
#
# 1. Use regex to handle spelling mistakes of the word "overwhelmed" (e.g., "Tension makes me uverwhelmed"), and respond with "Why do you feel overwhelmed?".
# 2. Use regex to handle spelling mistakes of the word "mother" (e.g., "I hate my mther").
#   Respond with "I think you meant "mother" instead of "mther". Tell me more about your mother."
#
#
# *These are the steps to solve question 3 using the notebook:*
#
# 1. Add the regex pairs to the pairs variable coded in the section - "Rules for Eliza".
# 2. Then rerun the demo() function to test your regex.

# %% [markdown]
# # Question 4: Synonyms
#
# Use regex to handle synonyms of the word "headache" - headache, migraine, nausea, sinus.
# * Respond with "Looks like you have severe symptoms. I suggest you should consult a doctor.", "I am just a chatbot. Please seek medical help."

# %% [markdown]
# # Question 5: Anchoring
# Insert additional regex for handling swear words in at the beginning of a sentence. For example, "Damn! I am so happy today.", "Crickey!I am so happy today!", "Bollocks! I am so happy today!"
# * Respond with "Hey! I think you should be careful with your language!"

# %% [markdown]
# # Question 6: Repetitions
#
# Insert additional regex for pairs variable for sentences that begin with exclamations: For example, "Wow! I am so happy today.", "Woooooowwwwwwwww! I am so happy today!", "Yaaaayyyyyy! I am so happy today!", "YYYeeaaaahhhhhhh! I am super happy today!"
#
# * Respond with "Wow! Looks like youre quite happy! Care to tell me more?"

# %% [markdown]
# # Question 7: Groups
#
# Insert additional regex for answering questions about multiple topics: For example, "I have been seeking help since 2017.", "I have been feeling low since 2020."
#
# * Respond with "So from 2017 you have been seeking help. How does that make you feel?",
#     "2020 is a long time ago. How do you feel about feeling low for so long?"
