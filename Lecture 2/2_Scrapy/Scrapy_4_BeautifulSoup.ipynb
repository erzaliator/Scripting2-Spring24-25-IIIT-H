# %% [markdown]
# ## Introduction to BeautifulSoup
#
# [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) is a popular Python library used for web scraping purposes to pull the data out of HTML and XML files. It creates parse trees from page source codes that can be used to extract data easily. BeautifulSoup works well with requests and other HTTP libraries, making it a powerful tool for crawling and scraping websites.
#
# ### Key Features of BeautifulSoup
#
# - **Parsing HTML/XML:** BeautifulSoup can parse and navigate HTML or XML documents, even those with poorly-formed markup.
# - **Searching the Parse Tree:** It provides simple methods for searching and navigating the parse tree, such as `find()`, `find_all()`, and CSS selectors.
# - **Modifying the Parse Tree:** You can modify the HTML/XML tree, extract text, and manipulate tags.
#
# ---
#
# ## How BeautifulSoup is Used in the Karachi Bakery Scraper
#
# Let's connect the main BeautifulSoup concepts to their usage in the code above:
#
# - **Downloading the Webpage:**
#   The code uses the `requests` library to fetch the HTML content of a webpage:
#   ```python
#   url = requests.get(site)
#   data = url.text

# %% [markdown]
# ### Parsing HTML with BeautifulSoup
#
# The HTML content is parsed using BeautifulSoup, which creates a parse tree for easy navigation:
#
# ```python
# soup = BeautifulSoup(data, 'lxml')
# ```

# %% [markdown]
# ### Finding all anchor tags
#
# To extract all the links from the page, the code uses the find_all('a') method, which returns all <a> tags (hyperlinks) in the HTML:
#
# ```
# anchors = soup.find_all('a')
# ```

# %% [markdown]
# ### Navigating and Extracting Data:
# Each anchor tag is processed to extract the href attribute (the actual URL), and relative links are converted to absolute URLs using Python's urljoin.
#
# ### Crawling Multiple Pages:
# The script keeps track of crawled URLs and uses a queue to visit new links found on each page, demonstrating how BeautifulSoup can be used in a simple web crawler.

# %% [markdown]
# BeautifulSoup, combined with requests, provides a straightforward way to scrape and crawl websites, as demonstrated in the Karachi Bakery scraper below.

# %% [markdown]
# ## 🎂 Scraping the entire bakery using BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup
import re

crawled_websites = set()   # Set to keep track of already crawled URLs
website_queue = []         # Queue for URLs to crawl

def is_url(link):
    # Checks using regex if 'link' is a valid url
    link = str(link)
    url = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*/\\,() ]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', link)
    x = (" ".join(url) == link)
    return x

def read_anchors(site):
    # Downloads the page and extracts all anchor tags
    url = requests.get(site)
    data = url.text
    soup = BeautifulSoup(data, 'lxml')
    anchors = soup.find_all('a')
    return anchors

def link_from_anchor(anchor, base_url):
    # Extracts href from anchor and converts relative links to absolute
    try:
        link = re.search('href="(.*?)"', str(anchor))[1]
        if link.startswith('/'):
            # Convert relative link to absolute using base_url
            from urllib.parse import urljoin
            link = urljoin(base_url, link)
    except:
        link = None
    return link

def get_links(site, filename):
    # Main crawling function
    # Adds the initial site to the queue if not already crawled
    if (site not in crawled_websites) and (site not in crawled_websites):
        website_queue.append(site)
    with open(filename, 'a') as f:
        while website_queue:
            if len(crawled_websites) > 100:
                # Limit crawl to 100 pages for safety
                break
            current_site = website_queue.pop(0)
            if current_site in crawled_websites:
                continue
            try:
                anchors = read_anchors(current_site)  # Get all links from the page
            except Exception as e:
                continue
            for anchor in anchors:
                link = link_from_anchor(anchor, current_site)  # Extract and normalize link
                # Only add valid, uncrawled, in-domain links to the queue and file
                if link and is_url(link) and ('karachibakery.com' in link) and (link not in crawled_websites):
                    website_queue.append(link)
                    f.write(link + "\n")
            crawled_websites.add(current_site)  # Mark as crawled

get_links("https://www.karachibakery.com/", "kaveri_ALLCAKES.txt")

# %%
crawled_websites #print some sample crawled websites
# Out:
# {'http://www.karachibakery.com/virtualtour/karachi-virtualtour.html',
#  'https://order.karachibakery.com',
#  'https://order.karachibakery.com/',
#  'https://order.karachibakery.com/pages/contact',
#  'https://order.karachibakery.com/pages/terms',
#  'https://order.karachibakery.com/shop',
#  'https://order.karachibakery.com/shop/account',
#  'https://order.karachibakery.com/shop/account/favourites',
#  'https://order.karachibakery.com/shop/c',
#  'https://order.karachibakery.com/shop/c/200g-packs_6055',
#  'https://order.karachibakery.com/shop/c/assorted-biscuits-pack_5344',
#  'https://order.karachibakery.com/shop/c/biscotti_5998',
#  'https://order.karachibakery.com/shop/c/buy-1-get-1-free_4942',
#  'https://order.karachibakery.com/shop/c/chocolate-biscuits_6000',
#  'https://order.karachibakery.com/shop/c/christmas-special-cakes_5262',
#  'https://order.karachibakery.com/shop/c/christmas-specials_8441',
#  'https://order.karachibakery.com/shop/c/cocoatini-exc-chocolate-collection_4943',
#  'https://order.karachibakery.com/shop/c/combination-of-fast-moving-products_5345',
#  'https://order.karachibakery.com/shop/c/dry-fruit-biscuits-range_5995',
#  'https://order.karachibakery.com/shop/c/famous_biscuits_1348',
#  'https://order.karachibakery.com/shop/c/fast-moving-chocolates_5199',
#  'https://order.karachibakery.com/shop/c/festive-gift-packs_4940',
#  'https://order.karachibakery.com/shop/c/gluten-free-range_5997',
#  'https://order.karachibakery.com/shop/c/gluten-free_6904',
#  'https://order.karachibakery.com/shop/c/healthy_biscuit_selection_1353',
#  'https://order.karachibakery.com/shop/c/karachi-bakerys-famous-biscuits_5198',
#  'https://order.karachibakery.com/shop/c/karachi-bakerys-full-range_6905',
#  'https://order.karachibakery.com/shop/c/karachi-chocolates_3602',
#  'https://order.karachibakery.com/shop/c/karachi-sweet-collection_3598',
#  'https://order.karachibakery.com/shop/c/karachis-namkeen-collection_5976',
#  'https://order.karachibakery.com/shop/c/muharram-special_7365',
#  'https://order.karachibakery.com/shop/c/nankhatai-biscuits_5994',
#  'https://order.karachibakery.com/shop/c/nuts_biscuit_selection_1352',
#  'https://order.karachibakery.com/shop/c/packed-sweets_5630',
#  'https://order.karachibakery.com/shop/c/pure-butter-biscuits-short-breads_5999',
#  'https://order.karachibakery.com/shop/c/sugar_free_biscuit_selection_1356',
#  'https://order.karachibakery.com/shop/c/veganism_5996',
#  'https://order.karachibakery.com/shop/fccyt6a5sr',
#  'https://order.karachibakery.com/shop/nkdnumsfxc/',
#  'https://order.karachibakery.com/shop/nkdnumsfxc/c',
#  'https://order.karachibakery.com/shop/sc/dussehra-diwali-special_12620',
#  'https://wa.me/+919100990871/?text=Hello! I visited your website (https://www.karachibakery.com/). I would like to get more information about your products.',
#  'https://web.whatsapp.com/send/?phone=%2B919100990871&amp;text=Hello%21+I+visited+your+website+%28https%3A%2F%2Fwww.karachibakery.com%2F%29.+I+would+like+to+get+more+information+about+your+products.&amp;type=phone_number&amp;app_absent=0',
#  'https://www.karachibakery.com/',
#  'https://www.karachibakery.com/1st-birthday-cakes1?pg=1',
#  'https://www.karachibakery.com/about-us',
#  'https://www.karachibakery.com/artisan-breads',
#  'https://www.karachibakery.com/assorted-biscuit-selection.php',
#  'https://www.karachibakery.com/barbie-cakes',
#  'https://www.karachibakery.com/birthday-cakes1?pg=1',
#  'https://www.karachibakery.com/birthday-cakes2?pg=2',
#  'https://www.karachibakery.com/birthday-cakes3?pg=3',
#  'https://www.karachibakery.com/biscotti-selection.php',
#  'https://www.karachibakery.com/business-enquiry',
#  'https://www.karachibakery.com/cake-rusk.php',
#  'https://www.karachibakery.com/child-cakes2?pg=2',
#  'https://www.karachibakery.com/child-cakes3?pg=3',
#  'https://www.karachibakery.com/child-cakes4?pg=4',
#  'https://www.karachibakery.com/child-cakes5?pg=5',
#  'https://www.karachibakery.com/child-cakes?pg=1',
#  'https://www.karachibakery.com/chocolate-biscuit-selection.php',
#  'https://www.karachibakery.com/chocolates',
#  'https://www.karachibakery.com/contact-us',
#  'https://www.karachibakery.com/cup-cakes',
#  'https://www.karachibakery.com/enquiry',
#  'https://www.karachibakery.com/general-enquiry',
#  'https://www.karachibakery.com/gift-packs',
#  'https://www.karachibakery.com/gluten-free-biscuit.php',
#  'https://www.karachibakery.com/gluten-free-biscuits.php',
#  'https://www.karachibakery.com/gluten-free-sugar-free-celebration-cakes.php',
#  'https://www.karachibakery.com/gluten-free-sugar-free-tea-cakes.php',
#  'https://www.karachibakery.com/health-biscuit-selection.php',
#  'https://www.karachibakery.com/health-biscuit.php',
#  'https://www.karachibakery.com/heart-cakes',
#  'https://www.karachibakery.com/home',
#  'https://www.karachibakery.com/karachi-biscuits',
#  'https://www.karachibakery.com/karachi-famous-biscuit.php',
#  'https://www.karachibakery.com/karachi-mithai',
#  'https://www.karachibakery.com/macaron',
#  'https://www.karachibakery.com/millets-vegan-biscuit.php',
#  'https://www.karachibakery.com/nankatai-selection.php',
#  'https://www.karachibakery.com/new-arrivals1?pg=1',
#  'https://www.karachibakery.com/new-cakes',
#  'https://www.karachibakery.com/nuts-biscuits-selection.php',
#  'https://www.karachibakery.com/pastries',
#  'https://www.karachibakery.com/pure-butter-biscuit.php',
#  'https://www.karachibakery.com/rusks',
#  'https://www.karachibakery.com/salt-biscuit-selection.php',
#  'https://www.karachibakery.com/services',
#  'https://www.karachibakery.com/short-bread-selection.php',
#  'https://www.karachibakery.com/sitemap',
#  'https://www.karachibakery.com/snacks',
#  'https://www.karachibakery.com/specialities',
#  'https://www.karachibakery.com/sugar-free-biscuits.php',
#  'https://www.karachibakery.com/testimonials',
#  'https://www.karachibakery.com/vegan-biscuits.php',
#  'https://www.karachibakery.com/wedding-cakes1?pg=1',
#  'https://www.karachibakery.com/wedding-cakes2?pg=2',
#  'https://www.karachibakery.com/wedding-cakes3?pg=3',
#  'https://www.karachibakery.com/wedding-cakes4?pg=4',
#  'https://www.urbandart.com/channel/2?utm_source=order.karachibakery.com&amp;utm_medium=ClientFooter&amp;utm_campaign=Image'}
